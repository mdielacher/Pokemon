# %%
import pandas as pd

# %%
evolution = pd.read_csv("Evolution.csv", encoding="UTF-8", delimiter=";")

# %%
evolution.head(5)
# Out:
#         Basic      Stage1      Stage2
# 0   Bulbasaur     Ivysaur    Venusaur
# 1  Charmander  Charmeleon   Charizard
# 2    Squirtle   Wartortle   Blastoise
# 3    Caterpie     Metapod  Butterfree
# 4      Weedle      Kakuna    Beedrill

# %%
evolution = evolution[["Unevolved Pokémon/Basic Pokémon", "First-Evolved Pokémon/Stage 1 Pokémon", "Second-Evolved/Stage 2"]]

# %%
# Umbenennen der Spalten für bessere Handhabbarkeit in evolution_stages
evolution.columns = ['Basic', 'Stage1', 'Stage2']

# %%
# Import clean Dataset as dataframe
path = "data\\preprocessed_pokemon_with_Evolution.csv"
df = pd.read_csv(path, encoding= "UTF-8")
df.head()
# Out:
#    Unnamed: 0           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0           0      Bulbasaur  Grass  Poison  45      49       49       65
# 1           1        Ivysaur  Grass  Poison  60      62       63       80
# 2           2       Venusaur  Grass  Poison  80      82       83      100
# 3           3  Mega Venusaur  Grass  Poison  80     100      123      122
# 4           4     Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Evolution
# 0       65     45           1      False        1.0
# 1       80     60           1      False        2.0
# 2      100     80           1      False        3.0
# 3      120     80           1      False        5.0
# 4       50     65           1      False        1.0

# %%
# Funktion zur Ermittlung der Evolutionsstufe
def find_stage(name):
    for column in evolution.columns[:]:  # Startet bei 1, um den 'index' zu überspringen
        if name in evolution[column].values:
            return column
    return 'Not Found'

# Anwenden der Funktion auf die Spalte 'Name' im DataFrame pokemon_stats
df['evolution_2'] = df['Name'].apply(find_stage)

# %%
df.head(30)
# Out:
#     Unnamed: 0              Name  Type 1  Type 2  HP  Attack  Defense  \
# 0            0         Bulbasaur   Grass  Poison  45      49       49
# 1            1           Ivysaur   Grass  Poison  60      62       63
# 2            2          Venusaur   Grass  Poison  80      82       83
# 3            3     Mega Venusaur   Grass  Poison  80     100      123
# 4            4        Charmander    Fire     NaN  39      52       43
# 5            5        Charmeleon    Fire     NaN  58      64       58
# 6            6         Charizard    Fire  Flying  78      84       78
# 7            7  Mega Charizard X    Fire  Dragon  78     130      111
# 8            8  Mega Charizard Y    Fire  Flying  78     104       78
# 9            9          Squirtle   Water     NaN  44      48       65
# 10          10         Wartortle   Water     NaN  59      63       80
# 11          11         Blastoise   Water     NaN  79      83      100
# 12          12    Mega Blastoise   Water     NaN  79     103      120
# 13          13          Caterpie     Bug     NaN  45      30       35
# 14          14           Metapod     Bug     NaN  50      20       55
# 15          15        Butterfree     Bug  Flying  60      45       50
# 16          16            Weedle     Bug  Poison  40      35       30
# 17          17            Kakuna     Bug  Poison  45      25       50
# 18          18          Beedrill     Bug  Poison  65      90       40
# 19          19     Mega Beedrill     Bug  Poison  65     150       40
# 20          20            Pidgey  Normal  Flying  40      45       40
# 21          21         Pidgeotto  Normal  Flying  63      60       55
# 22          22           Pidgeot  Normal  Flying  83      80       75
# 23          23      Mega Pidgeot  Normal  Flying  83      80       80
# 24          24           Rattata  Normal     NaN  30      56       35
# 25          25          Raticate  Normal     NaN  55      81       60
# 26          26           Spearow  Normal  Flying  40      60       30
# 27          27            Fearow  Normal  Flying  65      90       65
# 28          28             Ekans  Poison     NaN  35      60       44
# 29          29             Arbok  Poison     NaN  60      85       69
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary  Evolution evolution_2
# 0        65       65     45           1      False        1.0       Basic
# 1        80       80     60           1      False        2.0      Stage1
# 2       100      100     80           1      False        3.0      Stage2
# 3       122      120     80           1      False        5.0   Not Found
# 4        60       50     65           1      False        1.0       Basic
# 5        80       65     80           1      False        2.0      Stage1
# 6       109       85    100           1      False        3.0      Stage2
# 7       130       85    100           1      False        5.0   Not Found
# 8       159      115    100           1      False        5.0   Not Found
# 9        50       64     43           1      False        1.0       Basic
# 10       65       80     58           1      False        2.0      Stage1
# 11       85      105     78           1      False        3.0      Stage2
# 12      135      115     78           1      False        5.0   Not Found
# 13       20       20     45           1      False        1.0       Basic
# 14       25       25     30           1      False        2.0      Stage1
# 15       90       80     70           1      False        3.0      Stage2
# 16       20       20     50           1      False        1.0       Basic
# 17       25       25     35           1      False        2.0      Stage1
# 18       45       80     75           1      False        3.0      Stage2
# 19       15       80    145           1      False        5.0   Not Found
# 20       35       35     56           1      False        1.0       Basic
# 21       50       50     71           1      False        2.0      Stage1
# 22       70       70    101           1      False        3.0      Stage2
# 23      135       80    121           1      False        5.0   Not Found
# 24       25       35     72           1      False        1.0       Basic
# 25       50       70     97           1      False        2.0      Stage1
# 26       31       31     70           1      False        1.0       Basic
# 27       61       61    100           1      False        2.0      Stage1
# 28       40       54     55           1      False        1.0       Basic
# 29       65       79     80           1      False        2.0      Stage1

# %%
df.loc[(df['Name'].str.contains('Mega')) & (df['evolution_2'] == 'Not Found'), 'evolution_2'] = 'Mega'

# %%
df.loc[df["evolution_2"] == "Not Found"]
# Out:
#      Unnamed: 0                         Name    Type 1    Type 2   HP  Attack  \
# 270         270                        Ho-oh      Fire    Flying  106     130
# 422         422          KyogrePrimal Kyogre     Water       NaN  100     150
# 424         424               Primal Groudon    Ground      Fire  100     180
# 428         428        Deoxys (Normal Forme)   Psychic       NaN   50     150
# 429         429        Deoxys (Attack Forme)   Psychic       NaN   50     180
# 430         430       Deoxys (Defense Forme)   Psychic       NaN   50      70
# 431         431         Deoxys (Speed Forme)   Psychic       NaN   50      95
# 458         458       Wormadam (Plant Cloak)       Bug     Grass   60      59
# 459         459       Wormadam (Sandy Cloak)       Bug    Ground   60      79
# 460         460       Wormadam (Trash Cloak)       Bug     Steel   60      69
# 532         532                   Rotom Heat  Electric      Fire   50      65
# 533         533                   Rotom Wash  Electric     Water   50      65
# 534         534                  Rotom Frost  Electric       Ice   50      65
# 535         535                    Rotom Fan  Electric    Flying   50      65
# 536         536                    Rotom Mow  Electric     Grass   50      65
# 544         544     Giratina (Altered Forme)     Ghost    Dragon  150     100
# 545         545      Giratina (Origin Forme)     Ghost    Dragon  150     120
# 550         550         Shaymin (Land Forme)     Grass       NaN  100     100
# 551         551          Shaymin (Sky Forme)     Grass    Flying  100     103
# 615         615   Darmanitan (Standard Mode)      Fire       NaN  105     140
# 616         616        Darmanitan (Zen Mode)      Fire   Psychic  105      30
# 702         702   Tornadus (Incarnate Forme)    Flying       NaN   79     115
# 703         703     Tornadus (Therian Forme)    Flying       NaN   79     100
# 704         704  Thundurus (Incarnate Forme)  Electric    Flying   79     115
# 705         705    Thundurus (Therian Forme)  Electric    Flying   79     105
# 708         708   Landorus (Incarnate Forme)    Ground    Flying   89     125
# 709         709     Landorus (Therian Forme)    Ground    Flying   89     145
# 711         711                 Black Kyurem    Dragon       Ice  125     170
# 712         712                 White Kyurem    Dragon       Ice  125     120
# 713         713      Keldeo (Ordinary Forme)     Water  Fighting   91      72
# 714         714      Keldeo (Resolute Forme)     Water  Fighting   91      72
# 715         715         Meloetta (Aria Forme   )Normal   Psychic  100      77
# 716         716   Meloetta (Pirouette Forme)    Normal  Fighting  100     128
# 746         746              Meowstic - Male   Psychic       NaN   74      48
# 747         747            Meowstic - Female   Psychic       NaN   74      48
# 750         750      Aegislash (Blade Forme)     Steel     Ghost   60     150
# 751         751     Aegislash (Shield Forme)     Steel     Ghost   60      50
# 780         780     Pumpkaboo - Average Size     Ghost     Grass   49      66
# 781         781       Pumpkaboo - Small Size     Ghost     Grass   44      66
# 782         782       Pumpkaboo - Large Size     Ghost     Grass   54      66
# 783         783       Pumpkaboo - Super Size     Ghost     Grass   59      66
# 784         784     Gourgeist - Average Size     Ghost     Grass   65      90
# 785         785       Gourgeist - Small Size     Ghost     Grass   55      85
# 786         786       Gourgeist - Large Size     Ghost     Grass   75      95
# 787         787       Gourgeist - Super Size     Ghost     Grass   85     100
# 794         794          Zygarde (50% Forme)    Dragon    Ground  108     100
# 797         797               Hoopa Confined   Psychic     Ghost   80     110
# 798         798                Hoopa Unbound   Psychic      Dark   80     160
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  Evolution  \
# 270       90      110      154     90           2       True        0.0
# 422       90      180      160     90           3       True        NaN
# 424      160      150       90     90           3       True        5.0
# 428       50      150       50    150           3       True        0.0
# 429       20      180       20    150           3       True        0.0
# 430      160       70      160     90           3       True        0.0
# 431       90       95       90    180           3       True        0.0
# 458       85       79      105     36           4      False        2.0
# 459      105       59       85     36           4      False        2.0
# 460       95       69       95     36           4      False        2.0
# 532      107      105      107     86           4      False        0.0
# 533      107      105      107     86           4      False        0.0
# 534      107      105      107     86           4      False        0.0
# 535      107      105      107     86           4      False        0.0
# 536      107      105      107     86           4      False        0.0
# 544      120      100      120     90           4       True        0.0
# 545      100      120      100     90           4       True        0.0
# 550      100      100      100    100           4       True        0.0
# 551       75      120       75    127           4       True        0.0
# 615       55       30       55     95           5      False        2.0
# 616      105      140      105     55           5      False        2.0
# 702       70      125       80    111           5       True        0.0
# 703       80      110       90    121           5       True        0.0
# 704       70      125       80    111           5       True        0.0
# 705       70      145       80    101           5       True        0.0
# 708       90      115       80    101           5       True        0.0
# 709       90      105       80     91           5       True        0.0
# 711      100      120       90     95           5       True        0.0
# 712       90      170      100     95           5       True        0.0
# 713       90      129       90    108           5      False        0.0
# 714       90      129       90    108           5      False        0.0
# 715       77      128      128     90           5      False        NaN
# 716       90       77       77    128           5      False        0.0
# 746       76       83       81    104           6      False        2.0
# 747       76       83       81    104           6      False        2.0
# 750       50      150       50     60           6      False        3.0
# 751      150       50      150     60           6      False        3.0
# 780       70       44       55     51           6      False        1.0
# 781       70       44       55     56           6      False        1.0
# 782       70       44       55     46           6      False        1.0
# 783       70       44       55     41           6      False        1.0
# 784      122       58       75     84           6      False        2.0
# 785      122       58       75     99           6      False        2.0
# 786      122       58       75     69           6      False        2.0
# 787      122       58       75     54           6      False        2.0
# 794      121       81       95     95           6       True        0.0
# 797       60      150      130     70           6       True        0.0
# 798       60      170      130     80           6       True        0.0
#
#     evolution_2
# 270   Not Found
# 422   Not Found
# 424   Not Found
# 428   Not Found
# 429   Not Found
# 430   Not Found
# 431   Not Found
# 458   Not Found
# 459   Not Found
# 460   Not Found
# 532   Not Found
# 533   Not Found
# 534   Not Found
# 535   Not Found
# 536   Not Found
# 544   Not Found
# 545   Not Found
# 550   Not Found
# 551   Not Found
# 615   Not Found
# 616   Not Found
# 702   Not Found
# 703   Not Found
# 704   Not Found
# 705   Not Found
# 708   Not Found
# 709   Not Found
# 711   Not Found
# 712   Not Found
# 713   Not Found
# 714   Not Found
# 715   Not Found
# 716   Not Found
# 746   Not Found
# 747   Not Found
# 750   Not Found
# 751   Not Found
# 780   Not Found
# 781   Not Found
# 782   Not Found
# 783   Not Found
# 784   Not Found
# 785   Not Found
# 786   Not Found
# 787   Not Found
# 794   Not Found
# 797   Not Found
# 798   Not Found

# %%
df.loc[df["Legendary"]==True]
# Out:
#      Unnamed: 0            Name    Type 1    Type 2   HP  Attack  Defense  \
# 156         156        Articuno       Ice    Flying   90      85      100
# 157         157          Zapdos  Electric    Flying   90      90       85
# 158         158         Moltres      Fire    Flying   90     100       90
# 162         162          Mewtwo   Psychic       NaN  106     110       90
# 163         163   Mega Mewtwo X   Psychic  Fighting  106     190      100
# ..          ...             ...       ...       ...  ...     ...      ...
# 795         795         Diancie      Rock     Fairy   50     100      150
# 796         796    Mega Diancie      Rock     Fairy   50     160      110
# 797         797  Hoopa Confined   Psychic     Ghost   80     110       60
# 798         798   Hoopa Unbound   Psychic      Dark   80     160       60
# 799         799       Volcanion      Fire     Water   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Evolution evolution_2
# 156       95      125     85           1       True        0.0       Basic
# 157      125       90    100           1       True        0.0       Basic
# 158      125       85     90           1       True        0.0       Basic
# 162      154       90    130           1       True        0.0       Basic
# 163      154      100    130           1       True        5.0        Mega
# ..       ...      ...    ...         ...        ...        ...         ...
# 795      100      150     50           6       True        0.0       Basic
# 796      160      110    110           6       True        5.0        Mega
# 797      150      130     70           6       True        0.0   Not Found
# 798      170      130     80           6       True        0.0   Not Found
# 799      130       90     70           6       True        0.0       Basic
#
# [65 rows x 14 columns]

# %%
df.loc[(df['Legendary']==True) & (df['evolution_2'] == 'Not Found'), 'evolution_2'] = 'Basic'

# %%
df.loc[df["evolution_2"] == "Not Found"]
# Out:
#      Unnamed: 0                        Name    Type 1    Type 2   HP  Attack  \
# 458         458      Wormadam (Plant Cloak)       Bug     Grass   60      59
# 459         459      Wormadam (Sandy Cloak)       Bug    Ground   60      79
# 460         460      Wormadam (Trash Cloak)       Bug     Steel   60      69
# 532         532                  Rotom Heat  Electric      Fire   50      65
# 533         533                  Rotom Wash  Electric     Water   50      65
# 534         534                 Rotom Frost  Electric       Ice   50      65
# 535         535                   Rotom Fan  Electric    Flying   50      65
# 536         536                   Rotom Mow  Electric     Grass   50      65
# 615         615  Darmanitan (Standard Mode)      Fire       NaN  105     140
# 616         616       Darmanitan (Zen Mode)      Fire   Psychic  105      30
# 713         713     Keldeo (Ordinary Forme)     Water  Fighting   91      72
# 714         714     Keldeo (Resolute Forme)     Water  Fighting   91      72
# 715         715        Meloetta (Aria Forme   )Normal   Psychic  100      77
# 716         716  Meloetta (Pirouette Forme)    Normal  Fighting  100     128
# 746         746             Meowstic - Male   Psychic       NaN   74      48
# 747         747           Meowstic - Female   Psychic       NaN   74      48
# 750         750     Aegislash (Blade Forme)     Steel     Ghost   60     150
# 751         751    Aegislash (Shield Forme)     Steel     Ghost   60      50
# 780         780    Pumpkaboo - Average Size     Ghost     Grass   49      66
# 781         781      Pumpkaboo - Small Size     Ghost     Grass   44      66
# 782         782      Pumpkaboo - Large Size     Ghost     Grass   54      66
# 783         783      Pumpkaboo - Super Size     Ghost     Grass   59      66
# 784         784    Gourgeist - Average Size     Ghost     Grass   65      90
# 785         785      Gourgeist - Small Size     Ghost     Grass   55      85
# 786         786      Gourgeist - Large Size     Ghost     Grass   75      95
# 787         787      Gourgeist - Super Size     Ghost     Grass   85     100
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  Evolution  \
# 458       85       79      105     36           4      False        2.0
# 459      105       59       85     36           4      False        2.0
# 460       95       69       95     36           4      False        2.0
# 532      107      105      107     86           4      False        0.0
# 533      107      105      107     86           4      False        0.0
# 534      107      105      107     86           4      False        0.0
# 535      107      105      107     86           4      False        0.0
# 536      107      105      107     86           4      False        0.0
# 615       55       30       55     95           5      False        2.0
# 616      105      140      105     55           5      False        2.0
# 713       90      129       90    108           5      False        0.0
# 714       90      129       90    108           5      False        0.0
# 715       77      128      128     90           5      False        NaN
# 716       90       77       77    128           5      False        0.0
# 746       76       83       81    104           6      False        2.0
# 747       76       83       81    104           6      False        2.0
# 750       50      150       50     60           6      False        3.0
# 751      150       50      150     60           6      False        3.0
# 780       70       44       55     51           6      False        1.0
# 781       70       44       55     56           6      False        1.0
# 782       70       44       55     46           6      False        1.0
# 783       70       44       55     41           6      False        1.0
# 784      122       58       75     84           6      False        2.0
# 785      122       58       75     99           6      False        2.0
# 786      122       58       75     69           6      False        2.0
# 787      122       58       75     54           6      False        2.0
#
#     evolution_2
# 458   Not Found
# 459   Not Found
# 460   Not Found
# 532   Not Found
# 533   Not Found
# 534   Not Found
# 535   Not Found
# 536   Not Found
# 615   Not Found
# 616   Not Found
# 713   Not Found
# 714   Not Found
# 715   Not Found
# 716   Not Found
# 746   Not Found
# 747   Not Found
# 750   Not Found
# 751   Not Found
# 780   Not Found
# 781   Not Found
# 782   Not Found
# 783   Not Found
# 784   Not Found
# 785   Not Found
# 786   Not Found
# 787   Not Found

# %%
df.to_csv("pokemon_with_evolution.csv", index=False, encoding="UTF-8" )

# %%
df = pd.read_csv("pokemon_with_evolution_edited.csv", encoding="UTF-8", delimiter=";")
df.head()
# Out:
#             Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0      Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1        Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2       Venusaur  Grass  Poison  80      82       83      100      100     80
# 3  Mega Venusaur  Grass  Poison  80     100      123      122      120     80
# 4     Charmander   Fire     NaN  39      52       43       60       50     65
#
#    Generation  Legendary  Evolution evolution_2
# 0           1      False        1.0       Basic
# 1           1      False        2.0      Stage1
# 2           1      False        3.0      Stage2
# 3           1      False        5.0        Mega
# 4           1      False        1.0       Basic

# %%
df['check'] = (
    (df['Evolution'] == 1.0) & (df['evolution_2'] == 'Basic') |
    (df['Evolution'] == 2.0) & (df['evolution_2'] == 'Stage1') |
    (df['Evolution'] == 3.0) & (df['evolution_2'] == 'Stage2') |
    (df['Evolution'] == 5.0) & (df['evolution_2'] == 'Mega')
)

# %%
df.loc[df["check"] == False]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Lisa\anaconda3\envs\FH\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'check'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 df.loc[df["check"] == False]
#
# File c:\Users\Lisa\anaconda3\envs\FH\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File c:\Users\Lisa\anaconda3\envs\FH\Lib\site-packages\pandas\core\indexes\base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'check'

# %%
df = df.drop(columns=['Evolution','check'])

# %%
df.head()
# Out:
#             Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0      Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1        Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2       Venusaur  Grass  Poison  80      82       83      100      100     80
# 3  Mega Venusaur  Grass  Poison  80     100      123      122      120     80
# 4     Charmander   Fire     NaN  39      52       43       60       50     65
#
#    Generation  Legendary Evolution
# 0           1      False     Basic
# 1           1      False    Stage1
# 2           1      False    Stage2
# 3           1      False      Mega
# 4           1      False     Basic

# %%
df.rename(columns={'evolution_2': 'Evolution'}, inplace=True)

# %%
df.to_csv("pokemon_train_set.csv", encoding="UTF-8", index=False)
